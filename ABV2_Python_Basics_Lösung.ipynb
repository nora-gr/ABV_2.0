# %% [markdown]
# # ABV 2 – Python Basics
# ## Variablen & Rechnen · Strings · If/Else
#
# Dieses Übungsblatt besteht aus drei Themenblöcken:
#
# | # | Thema | Aufgaben |
# |---|-------|---------|
# | 1 | Variablen & Rechnen | 1 – 2 |
# | 2 | Strings & String-Funktionen | 3 – 5 |
# | 3 | If / Elif / Else | 6 – 7 |
#
# Bearbeiten Sie die Aufgaben der Reihe nach. Unter jeder Aufgabe finden Sie bei Bedarf aufklappbare Tipps.

# %% [markdown]
# ---
# ## Teil 1 – Variablen & Rechnen

# %% [markdown]
# ### Aufgabe 1 – Firmenverkauf
#
# Sie haben zusammen mit drei Kommilitonen eine Start-up-Firma gegründet. Ein Investor bietet euch **5.000.000 €** für die Übernahme.
#
# Die Aufteilung ist wie folgt:
# - **Josephine** (Geschäftsidee): 30 %
# - **Otto** (Kundenakquise): 25 %
# - **Paul** und **Sie** teilen den Rest – Sie erhalten jedoch zusätzlich einen Bonus von **400.000 €** für den größten gewonnenen Kunden.
#
# **a)** Speichern Sie den Gesamtgewinn in der Variable `profit` und den Bonus in `bonus`. Berechnen Sie die individuellen Anteile und geben Sie alle vier Werte aus.
#
# **b)** Schreiben Sie die Ausgabe aus **a)** als `"".format()`-Ausgabe oder nutzen sie `f-strings`.
#
# <details>
# <summary><b>Tipp zu a)</b></summary>
#
# Berechnen Sie zuerst Josephines und Ottos Anteile. Der verbleibende Betrag (`profit - josephine - otto`) wird zwischen Paul und Ihnen geteilt – vergessen Sie dabei Ihren Bonus nicht.
# </details>
#
# <details>
# <summary><b>Tipp zu b)</b></summary>
#
# Schreiben Sie den Ausgabebefehl aus a) als `"".format()`-Ausgabe, z.B.:
# ```python
# print("Josephine: {} €".format(josephine))
# ```
# oder nutzen sie `f-strings`
# ```python
# print(f"Josephine: {josephine} €")
# ```
# </details>

# %%
# Ihre Lösung hier:
profit = 5000000
bonus = 400000

anteil_josephine = 0.3
anteil_otto = 0.25
anteil_paul = (1 - (anteil_josephine + anteil_otto)) / 2
anteil_ich = anteil_paul

josephine = anteil_josephine * 5000000
otto = anteil_otto * 5000000
paul = anteil_paul * 5000000
ich = anteil_ich * 5000000 + bonus

insgesamt = josephine + otto + paul + ich
ist_gleich_alles = insgesamt == profit + bonus

summary = f"""
Josephine bekommt {josephine} Euro!
Otto bekommt {otto} Euro!
Paul bekommt {paul} Euro!
Ich bekomme {ich} Euro!

Insgesamt verteilt = {insgesamt}
Ist gleich? {ist_gleich_alles}!

"""

print(summary)
# Out:
# Josephine bekommt 1500000.0 Euro!
# Otto bekommt 1250000.0 Euro!
# Paul bekommt 1125000.0 Euro!
# Ich bekomme 1525000.0 Euro!
#
# Insgesamt verteilt = 5400000.0
# Ist gleich? True!

# %% [markdown]
# ### Aufgabe 2 – Seminargruppen
#
# Für ein neues Seminar haben sich **194 Studierende** angemeldet.
#
# **a)** Speichern Sie die Studierendenanzahl in der Variable `students`.
#
# **b)** Wie viele **3er-Gruppen** können gebildet werden? Berechnen Sie den Wert und speichern Sie ihn in einer neuen Variable.
#
# **c)** Wie viele Studierende bleiben ohne Gruppe übrig? Speichern Sie das Ergebnis ebenfalls in einer Variable.
#
# **d)** Geben Sie die Ergebnisse aus b) und c) mit `print()` aus.
#
# **e)** Nachträglich melden sich **43 weitere** Studierende an. Passen Sie `students` entsprechend an.
#
# **f)** Das Seminar erlaubt nun auch **5er-Gruppen**. Wie viele 5er- und 3er-Gruppen können mit der neuen Gesamtzahl gebildet werden (möglichst viele 5er-Gruppen zuerst)? Geben Sie das Ergebnis aus.
#
# <details>
# <summary><b>Tipp zu b) und c)</b></summary>
#
# Verwenden Sie die ganzzahlige Division `//` für die Anzahl der Gruppen und den Modulo-Operator `%` für den Rest.
# </details>
#
# <details>
# <summary><b>Tipp zu f)</b></summary>
#
# Berechnen Sie zuerst, wie viele 5er-Gruppen möglich sind (`students // 5`). Die verbleibenden Studierenden (`students % 5`) werden dann in 3er-Gruppen eingeteilt – schauen Sie, ob das exakt aufgeht.
# </details>

# %%
# Ihre Lösung hier:
#a-d
students = 194 + 43 # e)
dreiergruppen = students // 3
rest = students % 3

print(f"Es gibt {dreiergruppen} Gruppen, es bleiben {rest} Studierende übrig") 

# f)
students = 194 + 43 

max_fünf = students // 5
print(max_fünf)
# maximale 5er-Gruppen = 47
fünf = max_fünf - (max_fünf % 3) # größtes Vielfaches von 3 ≤ fives_max

# fünf = 47 - (47 % 3)
# fünf = 47 - 2
# fünf = 45

drei = (students - 5 * fünf) // 3

# drei = (237 - 5*45) // 3
# drei = (237 - 225) // 3
# drei = 12 // 3 = 4


print(f"5er-Gruppen: {fünf}")            # → 45
print(f"3er-Gruppen: {drei}")           # → 4
# Out:
# Es gibt 79 Gruppen, es bleiben 0 Studierende übrig
# 47
# 5er-Gruppen: 45
# 3er-Gruppen: 4

# %% [markdown]
# ---
# ## Teil 2 – Strings & String-Funktionen

# %% [markdown]
# ### Aufgabe 3 – Begrüßung mit Initialen
#
# Schreiben Sie ein Programm, das den/die Benutzer:in nach Vor- und Nachnamen fragt und ihn/sie anschließend mit den **Initialen** begrüßt (jeweils der erste Buchstabe von Vor- und Nachname).
#
# Danach wird gefragt, seit welchem Jahr das Studium begonnen wurde. Das Programm gibt aus, wann der **Bachelor voraussichtlich abgeschlossen** wird (3 Jahre später).
#
# **Gewünschter Output (Beispiel):**
# ```
# Wie lautet Ihr Vorname? Anna
# Wie lautet Ihr Nachname? Müller
# Hallo A.M., schön, Sie kennenzulernen!
# Seit welchem Jahr studieren Sie? 2023
# Voraussichtlicher Abschluss: 2026
# ```
#
# <details>
# <summary><b>Tipp 1 – Initialen</b></summary>
#
# Verwenden Sie Indexierung (`[0]`), um den ersten Buchstaben eines Strings zu erhalten, z.B. `vorname[0]`.
# </details>
#
# <details>
# <summary><b>Tipp 2 – Ausgabe</b></summary>
#
# Nutzen Sie einen F-String für die Begrüßung:
# ```python
# print(f"Hallo {vorname[0]}.{nachname[0]}., ...")
# ```
# </details>
#
# <details>
# <summary><b>Tipp 3 – Jahresberechnung</b></summary>
#
# Den Input aus `input()` erhalten Sie stets als String. Konvertieren Sie ihn mit `int()`, damit Sie damit rechnen können:
# ```python
# start_jahr = int(input("..."))
# ```
# </details>

# %%
# Ihre Lösung hier:
vorname = input("Wie lautet Ihr Vorname?")
nachname = input("Wie lautet Ihr Nachname?")
print(f"Hallo {vorname[0]}.{nachname[0]}, schön, Sie kennenzulernen!")

studium = int(input("Seit welchem Jahr studieren Sie?"))
studium_end = studium + 3

print(f"Voraussichtlicher Abschluss: {studium_end}")
# Out:
# Wie lautet Ihr Vorname? Mick
# Wie lautet Ihr Nachname? Molitor
# Hallo M.M, schön, Sie kennenzulernen!
# Seit welchem Jahr studieren Sie? 2018
# Voraussichtlicher Abschluss: 2021

# %% [markdown]
# ### Aufgabe 4 – URL-Bereinigung
#
# Für eine Marktanalyse sollen URLs von Unterseiten auf ihre Hauptdomain gekürzt werden.
#
# Formatieren Sie die folgende URL so, dass nur noch `https://www.cactusking.com` ausgegeben wird. Verwenden Sie mindestens eine String-Funktion.
#
# <details>
# <summary><b>Tipp 1</b></summary>
#
# Mit welcher Methode können Sie einen String an einem bestimmten Zeichen **trennen**? (`split()`)
# </details>
#
# <details>
# <summary><b>Tipp 2</b></summary>
#
# `split('/')` teilt den String an jedem `/`. Das Ergebnis ist eine Liste – wählen Sie das richtige Element per Index aus.
# </details>
#
# <details>
# <summary><b>Tipp 3 – kompakter Weg</b></summary>
#
# Sie können `split()` und Indexierung kombinieren:
# ```python
# url.split('/sharp')[0]
# ```
# </details>

# %%
url = 'https://www.cactusking.com/sharp-spikes/juice'

# Ihre Lösung hier:
#element = url.split("/sharp")[0]

#print(element)

# oder
element = url.split('/') 
new = element[0] + element[2]
new = new.replace(":","://")
print(new)
# Out:
# https://www.cactusking.com

# %% [markdown]
# ### Aufgabe 5 – Preis-Berechnung
#
# Ergänzen Sie den untenstehenden Code, sodass folgender Output entsteht:
#
# ```
# Bier: 3.5 Euro
# Discount: 30%
# Gesamtpreis: 2.45 Euro
# ```
#
# <details>
# <summary><b>Tipp 1 – total_price</b></summary>
#
# Der Gesamtpreis ergibt sich aus dem Originalpreis abzüglich des Rabatts:
# `price_beer * (1 - beer_discount)`
# </details>
#
# <details>
# <summary><b>Tipp 2 – F-String</b></summary>
#
# Verwenden Sie einen mehrzeiligen F-String mit `\n` als Zeilenumbruch. Den Prozentwert können Sie direkt im F-String berechnen: `{beer_discount * 100:.0f}`
# </details>

# %%
drink = 'Bier'
price_beer = 3.5
beer_discount = 0.3
total_price = round(price_beer * (1-beer_discount), 2)-

bill = f"Bier: {price_beer} Euro \nDiscount: {beer_discount * 100}% \nGesamtpreis: {total_price} Euro"

bill = f"""
Bier: {price_beer} Euro
Discount: {beer_discount * 100}% 
Gesamtpreis: {total_price} Euro
"""

print(bill)
# Out:
# Bier: 3.5 Euro
# Discount: 30.0%
# Gesamtpreis: 2.45 Euro

# %% [markdown]
# ---
# ## Teil 3 – If / Elif / Else

# %% [markdown]
# ### Aufgabe 6 – Float-Erkennung
#
# **a)** Schreiben Sie ein Programm, das den/die Benutzer:in nach einer Zahl fragt und mithilfe einer Bedingung ausgibt, ob es sich um eine **Gleitkommazahl (Float)** handelt oder nicht.
#
# **b)** Falls die eingegebene Zahl ein Float ist, wandeln Sie sie in den Datentyp `float` um und geben Sie das Ergebnis aus.
#
# *Hinweis: Floats enthalten in der englischen Schreibweise einen Punkt (`.`).*
#
# <details>
# <summary><b>Tipp 1</b></summary>
#
# Was enthält jedes Float genau einmal? Mit welcher Funktion können Sie prüfen, wie oft ein Zeichen in einem String vorkommt? (`count()`)
# </details>
#
# <details>
# <summary><b>Tipp 2</b></summary>
#
# Ein Float besteht außer dem Punkt nur aus Ziffern. Mit `isdigit()` können Sie prüfen, ob ein String nur Zahlen enthält – der Punkt stört dabei jedoch. Entfernen Sie ihn vorher mit `replace('.', '')`.
# </details>
#
# <details>
# <summary><b>Tipp 3 – Bedingung kombinieren</b></summary>
#
# Verknüpfen Sie beide Bedingungen mit `and`:
# ```python
# if zahl.count('.') == 1 and zahl.replace('.', '').isdigit():
# ```
# </details>

# %%
# Ihre Lösung hier:
user_eingabe = input("Gebe eine Zahl ein!:")

if user_eingabe.count(".") == 1 and user_eingabe.replace(".", "").isdigit():
    print("Das war ein Float")
    user_eingabe = float(user_eingabe)
    print(f"Jetzt ist user_eingabe type = {type(user_eingabe)}")
else:
    print("Das war kein Float")
# Out:
# Gebe eine Zahl ein!: 1.5
# Das war ein Float
# Jetzt ist user_eingabe type = <class 'float'>

# %% [markdown]
# ### Aufgabe 7 – Zu spät zur Vorlesung?
#
# **a)** Generieren Sie eine zufällige Minutenzahl zwischen 0 und 200 (`randint` aus dem Modul `random`). Legen Sie anhand der folgenden Regeln mit `if / elif / else` fest, welche Meldung ausgegeben wird:
#
# | Minuten | Ausgabe |
# |---------|--------|
# | 0 | Sie sind pünktlich |
# | 1 – 15 | Noch im akademischen Viertel |
# | 16 – 30 | Noch zur ersten halben Stunde geschafft |
# | 31 – 100 | Viel, aber nicht alles verpasst |
# | 101 – 129 | Fast alles verpasst |
# | ≥ 130 | Alles verpasst |
#
# **b)** Zusätzlich kann es vorkommen, dass die Lehrperson nicht erscheint. Legen Sie eine Variable an, die zufällig `True` oder `False` enthält (`choice()` aus `random`). Ergänzen Sie folgende Sonderfälle:
#
# - Lehrperson fehlt & Sie pünktlich → *"Sie haben sich umsonst beeilt"*
# - Lehrperson erscheint & Sie pünktlich → *"Sie haben es geschafft!"*
# - Lehrperson fehlt & Sie zu spät → *"Sie haben nichts verpasst – aber sind umsonst gekommen"*
#
# Geben Sie die zufällig generierten Werte zur Überprüfung mit aus.
#
# <details>
# <summary><b>Tipp 1 – Imports & Zufallswerte</b></summary>
#
# ```python
# from random import randint, choice
# minuten = randint(0, 200)
# prof_fehlt = choice([True, False])
# ```
# </details>
#
# <details>
# <summary><b>Tipp 2 – Struktur</b></summary>
#
# Beginnen Sie mit `if minuten == 0`, gefolgt von mehreren `elif`-Blöcken und einem abschließenden `else`. Zeichnen Sie sich den Control-Flow auf, bevor Sie tippen.
# </details>
#
# <details>
# <summary><b>Tipp 3 – Teil b) einbauen</b></summary>
#
# Den Sonderfall "Pünktlich" können Sie mit einem **verschachtelten If** innerhalb des `if minuten == 0`-Blocks lösen:
# ```python
# if minuten == 0:
#     if prof_fehlt:
#         print("Sie haben sich umsonst beeilt")
#     else:
#         print("Sie haben es geschafft!")
# ```
# Den Sonderfall "Zu spät & Lehrperson fehlt" können Sie mit `and` in einer der `elif`-Bedingungen kombinieren.
# </details>

# %%
# Ihre Lösung hier:
from random import randint, choice

lehrperson = choice([True, False])
zufallszahl = randint(0, 200)
print(f"Zufallszahl: {zufallszahl}")
print(f"Lehrperson war da? {lehrperson}")

if zufallszahl == 0:
    if not lehrperson:
        print("Sie haben sich umsonst beeilt")
    else:
        print("Sie haben es geschafft!")
elif not lehrperson and zufallszahl != 0:
    print("Sie haben nichts verpasst – aber sind umsonst gekommen")
elif zufallszahl > 0 and zufallszahl <= 15:
    print("Noch im akademischen Viertel")
elif zufallszahl > 15 and zufallszahl <= 30:
    print("Noch zur ersten halben Stunde geschafft")
elif zufallszahl > 30 and zufallszahl <= 100:
    print("Viel aber nicht alles verpasst")
elif zufallszahl > 100 and zufallszahl <= 129:
    print("Fast alles verpasst")
else:
    print("Alles verpasst")
# Out:
# Zufallszahl: 133
# Lehrperson war da? False
# Sie haben nichts verpasst – aber sind umsonst gekommen

# %%
help(randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %% [markdown]
# ---
# ## Hausaufgabe – Kinoabend-Kalkulator

# %% [markdown]
# ### Hausaufgabe – Kinoabend-Kalkulator
#
# Eine Gruppe von Studierenden plant einen Kinoabend. Schreiben Sie Code, welcher alle anfallenden Kosten berechnet, die Ausgabe sauber formatiert und je nach Situation eine passende Meldung ausgibt.
#
# Die Aufgabe verbindet Variablen & Rechnen, String-Formatierung und If/Elif/Else.
#
# ---
#
# **a) Eingabe & Berechnung (Variablen & Rechnen)**
#
# Fragen Sie die Benutzerin / den Benutzer nach:
# - Vornamen und Nachnamen
# - Anzahl der Personen in der Gruppe
# - ob Studierende oder nicht (`"j"` / `"n"`)
#
# Gelten folgende Preise:
#
# | | Normal | Studierenden-Rabatt |
# |---|---|---|
# | Kinokarte | 12,00 € | 8,50 € |
# | Popcorn (optional) | 4,50 € | 4,50 € |
#
# Fragen Sie zusätzlich, ob Popcorn gewünscht wird (`"j"` / `"n"`). Berechnen Sie die **Gesamtkosten für die gesamte Gruppe**.
#
# ---
#
# **b) Formatierte Ausgabe (Strings)**
#
# Geben Sie eine Quittung aus, die folgendes Format hat (Beispiel):
#
# ```
# =============================
# Kinoabend-Kalkulator
# =============================
# Hallo A.M.!
# Personen:     4
# Ticket:       8.50 € pro Person
# Popcorn:      ja
# Gesamtkosten: 52.00 €
# =============================
# ```
#
# Verwenden Sie für die Ausgabe einen F-String. Die Initialen sollen wie in Aufgabe 3 aus Vor- und Nachnamen gebildet werden.
#
# ---
#
# **c) Situationsabhängige Meldung (If/Elif/Else)**
#
# Geben Sie nach der Quittung eine Meldung aus, die von den Gesamtkosten abhängt:
#
# | Gesamtkosten | Meldung |
# |---|---|
# | unter 20 € | *„Günstig! Genug für Popcorn-Nachschlag."* |
# | 20 € bis 49,99 € | *„Solider Abend – viel Spaß!"* |
# | 50 € bis 99,99 € | *„Großer Abend – lohnt sich bestimmt!"* |
# | 100 € oder mehr | *„Das wird teuer – hoffentlich ist der Film gut!"* |
#
# ---
#
# <details>
# <summary><b>Tipp zu a) – Preis je nach Rabatt wählen</b></summary>
#
# Speichern Sie den Ticketpreis in einer Variablen und setzen Sie ihn abhängig von der Eingabe:
# ```python
# if ist_student == "j":
#     ticket_preis = 8.50
# else:
#     ticket_preis = 12.00
# ```
# </details>
#
# <details>
# <summary><b>Tipp zu b) – Formatierung mit F-String</b></summary>
#
# Mit `:.2f` formatieren Sie Dezimalzahlen auf zwei Nachkommastellen:
# ```python
# f"Gesamtkosten: {gesamt:.2f} €"
# ```
# Die Initialen erhalten Sie wie in Aufgabe 3 über Indexierung: `vorname[0]` und `nachname[0]`.
# </details>
#
# <details>
# <summary><b>Tipp zu c) – Struktur</b></summary>
#
# Beginnen Sie mit `if gesamt < 20`, gefolgt von `elif`-Blöcken für die weiteren Bereiche und einem abschließenden `else`.
# </details>

# %%
# Ihre Lösung hier:
vorname = input("Wie ist ihr Vorname?")
nachname = input("Wie ist ihr Nachname?")
gruppen_größe = int(input("Anzahl der Personen in der Gruppe?"))
studierende = input("Seit ihr Studierende? (j oder n)")
popcorn = input("Wollt ihr Popcorn? (j oder n)")

if popcorn == "j":
    is_popcorn = "Ja"
else: 
    is_popcorn = "Nein"

gesamtpreis = 0
if studierende == "j":
    gesamtpreis += gruppen_größe * 8.50
    ticket_preis = 8.50
else:
    gesamtpreis += gruppen_größe * 12.0
    ticket_preis = 12.00

if is_popcorn == "Ja":
    gesamtpreis += gruppen_größe * 4.50

if gesamtpreis <= 20.00:
    zusatz = "Günstig! Genug für Popcorn-Nachschlag."
elif gesamtpreis > 20.00 and gesamtpreis <= 49.99:
    zusatz = "Solider Abend – viel Spaß!"
elif gesamtpreis > 49.99 and gesamtpreis <= 99.99:
    zusatz = "Großer Abend – lohnt sich bestimmt!"
else:
    zusatz = "Das wird teuer – hoffentlich ist der Film gut"

rechnung = f"""
=============================
Kinoabend-Kalkulator
=============================
Hallo {vorname[0]}.{nachname[0]}.!
Personen:     {gruppen_größe}
Ticket:       {ticket_preis} € pro Person
Popcorn:      {is_popcorn}
Gesamtkosten: {gesamtpreis} €
=============================
{zusatz}
=============================
"""
print(rechnung)
# Out:
# Wie ist ihr Vorname? Mick
# Wie ist ihr Nachname? Molitor
# Anzahl der Personen in der Gruppe? 4
# Seit ihr Studierende? (j oder n) j
# Wollt ihr Popcorn? (j oder n) n
# ...
# Kinoabend-Kalkulator
# ...
# Hallo M.M.!
# Personen:     4
# Ticket:       8.5 € pro Person
# Popcorn:      Nein
# Gesamtkosten: 34.0 €
# ...
# Solider Abend – viel Spaß!
# ...
